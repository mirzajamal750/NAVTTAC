# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from jupyter_datatables import init_datatables_mode

# %%
init_datatables_mode()
# Out:
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# /tmp/ipykernel_9342/4013572414.py in <module>
# ----> 1 init_datatables_mode()
#
# ~/.local/lib/python3.10/site-packages/jupyter_datatables/__init__.py in init_datatables_mode(options, classes)
#      94     extensions = config.defaults.extensions
#      95
# ---> 96     require("d3", "https://d3js.org/d3.v5.min")
#      97     require("d3-array", "https://d3js.org/d3-array.v2.min")
#      98
#
# ~/.local/lib/python3.10/site-packages/jupyter_require/core.py in __call__(self, library, path, *args, **kwargs)
#     110         :param path: str, path (url) to the library without .js suffix
#     111         """
# --> 112         self.config({library: path}, shim=kwargs.pop('shim', {}))
#     113
#     114     @property
#
# ~/.local/lib/python3.10/site-packages/jupyter_require/core.py in config(self, paths, shim)
#     199
#     200         if not self.is_initialized:
# --> 201             raise CommError("Comms haven't been initialized properly.")
#     202
#     203         RequireJS.__LIBS.update(paths)
#
# CommError: Comms haven't been initialized properly.. HINT: Try reloading <F5> the window.

# %%
data=pd.read_excel("career_pred.xlsx")

# %%
data
# Out:
#       sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 0        2    3     2            3                   1               1
# 1        3    1     2            2                   2               1
# 2        3    4     2            2                   1               1
# 3        3    4     2            1                   1               1
# 4        2    3     2            4                   1               1
# ...    ...  ...   ...          ...                 ...             ...
# 7520     3    2     1            2                   1               1
# 7521     2    3     3            3                   4               3
# 7522     3    2     1            2                   1               1
# 7523     2    1     1            1                   2               1
# 7524     2    2     2            3                   2               1
#
#       coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# 0                 1               1                     2                  4
# 1                 1               3                     2                  4
# 2                 1               2                     3                  3
# 3                 1               1                     3                  2
# 4                 1               4                     3                  3
# ...             ...             ...                   ...                ...
# 7520              2               2                     3                  3
# 7521              2               1                     3                  3
# 7522              1               2                     2                  3
# 7523              1               2                     2                  2
# 7524              1               1                     2                  3
#
#       ...  technology_used  sympos_attend  sympos_won  extracurricular  \
# 0     ...                1              3           1                2
# 1     ...                2              3           2                3
# 2     ...                1              4           3                1
# 3     ...                1              3           2                1
# 4     ...                1              2           1                3
# ...   ...              ...            ...         ...              ...
# 7520  ...                1              4           2                2
# 7521  ...                4              2           3                2
# 7522  ...                1              3           1                1
# 7523  ...                1              3           2                1
# 7524  ...                1              4           1                1
#
#       learning_style  college_bench  clg_teachers_know  college_performence   \
# 0                  2              4                  3                     4
# 1                  2              5                  3                     3
# 2                  4              3                  3                     3
# 3                  2              1                  4                     4
# 4                  1              5                  4                     3
# ...              ...            ...                ...                   ...
# 7520               1              4                  4                     3
# 7521               4              1                  3                     3
# 7522               3              5                  3                     3
# 7523               2              4                  4                     3
# 7524               3              5                  3                     3
#
#       college_skills                ROLE
# 0                  5   Technical Support
# 1                  4  Software Developer
# 2                  4      UI&UX Designer
# 3                  3   Technical Support
# 4                  1        Data Analyst
# ...              ...                 ...
# 7520               3                 NaN
# 7521               2                 NaN
# 7522               4                 NaN
# 7523               4                 NaN
# 7524               5                 NaN
#
# [7525 rows x 26 columns]

# %%
data.dtypes
# Out:
# sslc                     int64
# hsc                      int64
# cgpa                     int64
# school_type              int64
# no_of_miniprojects       int64
# no_of_projects           int64
# coresub_skill            int64
# aptitude_skill           int64
# problemsolving_skill     int64
# programming_skill        int64
# abstractthink_skill      int64
# design_skill             int64
# first_computer           int64
# first_program            int64
# lab_programs             int64
# ds_coding                int64
# technology_used          int64
# sympos_attend            int64
# sympos_won               int64
# extracurricular          int64
# learning_style          object
# college_bench            int64
# clg_teachers_know        int64
# college_performence      int64
# college_skills           int64
# ROLE                    object
# dtype: object

# %%
def convert_to_int(remain_df, col_name):
    new_df = remain_df.copy()  # create a copy of the original dataframe
    new_df[col_name] = pd.to_numeric(new_df[col_name], errors='coerce').astype('Int64')  # convert the specified column to int64
    return new_df

df = convert_to_int(data, 'learning_style')
# print(df.dtypes)
new_df=df.drop("ROLE", axis=1)

# %%
df.dtypes
# Out:
# sslc                     int64
# hsc                      int64
# cgpa                     int64
# school_type              int64
# no_of_miniprojects       int64
# no_of_projects           int64
# coresub_skill            int64
# aptitude_skill           int64
# problemsolving_skill     int64
# programming_skill        int64
# abstractthink_skill      int64
# design_skill             int64
# first_computer           int64
# first_program            int64
# lab_programs             int64
# ds_coding                int64
# technology_used          int64
# sympos_attend            int64
# sympos_won               int64
# extracurricular          int64
# learning_style           Int64
# college_bench            int64
# clg_teachers_know        int64
# college_performence      int64
# college_skills           int64
# ROLE                    object
# dtype: object

# %%
new_df=df.drop("ROLE", axis=1)

# group the data by the "Group" column
groups = data.groupby("ROLE")

# loop through each group and save the data to a CSV file
for name, group in groups:
    filename = f"{name}.csv"
    group.to_csv(filename, index=False)

# %%
new_df = new_df.dropna()
test=data.iloc[:49,:]
test_Y=test.iloc[:,25]
test_X=test.drop("ROLE", axis=1)
test_X
label_data=data.iloc[:49,:]
test_X
# Out:
#     sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 0      2    3     2            3                   1               1
# 1      3    1     2            2                   2               1
# 2      3    4     2            2                   1               1
# 3      3    4     2            1                   1               1
# 4      2    3     2            4                   1               1
# 5      1    1     1            1                   1               1
# 6      3    3     2            2                   2               1
# 7      3    3     2            2                   1               1
# 8      3    2     3            3                   1               1
# 9      4    4     2            2                   1               1
# 10     4    4     2            2                   1               1
# 11     4    4     3            1                   1               1
# 12     3    3     3            2                   1               1
# 13     4    4     2            2                   1               1
# 14     4    3     1            1                   1               1
# 15     4    3     3            2                   1               1
# 16     2    3     1            2                   2               1
# 17     4    4     4            2                   2               1
# 18     3    3     2            1                   1               1
# 19     4    4     4            2                   2               1
# 20     2    2     2            2                   1               1
# 21     4    4     3            2                   1               1
# 22     1    1     2            3                   3               3
# 23     4    4     4            1                   2               2
# 24     4    4     3            2                   2               1
# 25     3    3     3            1                   1               1
# 26     3    3     2            1                   1               1
# 27     4    4     2            2                   2               1
# 28     2    4     2            3                   2               2
# 29     4    4     4            3                   2               1
# 30     3    4     1            2                   1               1
# 31     4    4     3            2                   2               1
# 32     4    4     3            3                   1               1
# 33     4    4     4            2                   2               1
# 34     4    4     3            2                   1               1
# 35     4    2     2            1                   1               1
# 36     4    4     3            2                   1               1
# 37     4    4     3            2                   2               1
# 38     4    4     4            2                   1               1
# 39     4    3     3            3                   2               1
# 40     4    4     4            2                   2               1
# 41     4    3     2            2                   1               1
# 42     1    1     2            2                   2               2
# 43     4    3     2            2                   2               1
# 44     3    3     3            2                   1               2
# 45     3    3     1            1                   1               1
# 46     4    3     2            1                   2               1
# 47     2    3     2            3                   1               1
# 48     4    3     3            2                   2               1
#
#     coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# 0               1               1                     2                  4
# 1               1               3                     2                  4
# 2               1               2                     3                  3
# 3               1               1                     3                  2
# 4               1               4                     3                  3
# 5               2               2                     3                  2
# 6               2               4                     3                  3
# 7               2               1                     2                  2
# 8               1               2                     3                  5
# 9               2               2                     3                  3
# 10              1               3                     3                  2
# 11              1               4                     3                  2
# 12              2               4                     2                  3
# 13              2               3                     3                  3
# 14              2               4                     3                  3
# 15              2               3                     3                  2
# 16              2               3                     3                  4
# 17              1               4                     2                  3
# 18              1               1                     2                  2
# 19              2               4                     3                  4
# 20              2               3                     4                  5
# 21              2               1                     3                  3
# 22              2               3                     3                  3
# 23              2               4                     3                  3
# 24              1               1                     2                  3
# 25              1               2                     4                  2
# 26              2               2                     3                  3
# 27              2               4                     3                  3
# 28              2               2                     2                  3
# 29              1               1                     2                  3
# 30              2               2                     2                  2
# 31              1               4                     2                  3
# 32              1               4                     2                  3
# 33              1               2                     3                  3
# 34              2               2                     3                  3
# 35              2               2                     3                  3
# 36              2               2                     3                  3
# 37              2               1                     3                  4
# 38              2               2                     3                  5
# 39              2               1                     3                  3
# 40              2               4                     2                  3
# 41              2               2                     2                  2
# 42              2               1                     1                  2
# 43              2               1                     2                  3
# 44              1               2                     2                  2
# 45              2               1                     4                  2
# 46              1               1                     3                  3
# 47              2               1                     2                  3
# 48              1               1                     3                  3
#
#     ...  ds_coding  technology_used  sympos_attend  sympos_won  \
# 0   ...          1                1              3           1
# 1   ...          2                2              3           2
# 2   ...          1                1              4           3
# 3   ...          2                1              3           2
# 4   ...          2                1              2           1
# 5   ...          2                1              3           2
# 6   ...          1                1              3           2
# 7   ...          1                1              3           3
# 8   ...          1                1              3           3
# 9   ...          2                1              1           2
# 10  ...          3                1              3           3
# 11  ...          2                1              2           3
# 12  ...          3                1              3           1
# 13  ...          2                1              3           1
# 14  ...          3                1              3           2
# 15  ...          3                1              4           1
# 16  ...          4                1              3           3
# 17  ...          3                1              4           5
# 18  ...          2                1              3           1
# 19  ...          3                1              3           2
# 20  ...          2                2              3           2
# 21  ...          1                1              3           1
# 22  ...          2                2              3           3
# 23  ...          2                2              4           2
# 24  ...          1                1              3           2
# 25  ...          1                1              3           2
# 26  ...          2                1              4           3
# 27  ...          2                1              3           2
# 28  ...          2                1              3           3
# 29  ...          2                1              3           1
# 30  ...          2                1              4           1
# 31  ...          2                2              2           2
# 32  ...          2                1              3           3
# 33  ...          2                1              3           5
# 34  ...          2                3              4           2
# 35  ...          3                1              1           1
# 36  ...          2                1              3           1
# 37  ...          3                1              2           2
# 38  ...          2                1              3           2
# 39  ...          2                1              4           1
# 40  ...          4                1              4           1
# 41  ...          2                1              1           2
# 42  ...          1                1              3           2
# 43  ...          2                1              1           2
# 44  ...          2                1              4           2
# 45  ...          2                1              3           2
# 46  ...          2                1              1           1
# 47  ...          1                1              1           1
# 48  ...          2                1              1           1
#
#     extracurricular  learning_style  college_bench  clg_teachers_know  \
# 0                 2               2              4                  3
# 1                 3               2              5                  3
# 2                 1               4              3                  3
# 3                 1               2              1                  4
# 4                 3               1              5                  4
# 5                 1               2              5                  3
# 6                 1               1              5                  4
# 7                 3               4              5                  4
# 8                 3               2              5                  4
# 9                 2               3              5                  4
# 10                3               2              5                  4
# 11                1               1              3                  4
# 12                2               2              5                  4
# 13                1               2              5                  2
# 14                2               2              5                  4
# 15                2               2              4                  4
# 16                1               1              3                  4
# 17                1               1              5                  4
# 18                4               2              5                  4
# 19                3               2              5                  4
# 20                3               2              4                  3
# 21                3               3              5                  3
# 22                4               2              3                  1
# 23                1               3              3                  4
# 24                2               3              5                  3
# 25                1               2              4                  4
# 26                3               2              4                  3
# 27                3               4              2                  4
# 28                2               4              4                  4
# 29                3               1              4                  4
# 30                1               1              4                  3
# 31                1               1              4                  3
# 32                1               4              3                  4
# 33                3               2              4                  3
# 34                1               2              4                  4
# 35                1               2              4                  4
# 36                1               3              4                  3
# 37                1               1              4                  3
# 38                1               2              5                  3
# 39                4               4              4                  4
# 40                1               4              4                  4
# 41                2               2              2                  3
# 42                2               1              3                  4
# 43                1               1              4                  4
# 44                3               2              5                  4
# 45                1               3              4                  4
# 46                1               2              5                  4
# 47                2               3              4                  3
# 48                4               2              4                  3
#
#     college_performence   college_skills
# 0                      4               5
# 1                      3               4
# 2                      3               4
# 3                      4               3
# 4                      3               1
# 5                      3               5
# 6                      4               4
# 7                      3               3
# 8                      3               3
# 9                      4               5
# 10                     4               3
# 11                     4               4
# 12                     4               3
# 13                     3               4
# 14                     4               3
# 15                     4               3
# 16                     3               5
# 17                     4               4
# 18                     3               5
# 19                     4               4
# 20                     4               4
# 21                     4               1
# 22                     4               5
# 23                     4               4
# 24                     3               3
# 25                     3               3
# 26                     3               4
# 27                     4               5
# 28                     3               3
# 29                     3               1
# 30                     3               3
# 31                     4               3
# 32                     4               1
# 33                     4               1
# 34                     4               2
# 35                     3               5
# 36                     3               1
# 37                     3               4
# 38                     4               2
# 39                     4               5
# 40                     4               3
# 41                     3               1
# 42                     3               5
# 43                     3               4
# 44                     4               1
# 45                     3               1
# 46                     3               3
# 47                     3               1
# 48                     3               5
#
# [49 rows x 25 columns]

# %%
# Apply KMeans clustering to the scaled unlabeled data
kmeans = KMeans(n_clusters=8, random_state=42)
kmeans.fit(new_df)
# Out:
# /home/mirza/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(random_state=42)

# %%
# Apply MinMax scaling on the numerical columns
test_X = scaler.fit_transform(new_df)
test_clusters = kmeans.predict(test_X)

# View the count of samples in each predicted cluster
print(pd.Series(test_clusters).value_counts())


# Initialize the scaler
scaler = MinMaxScaler()

# Apply MinMax scaling on the numerical columns
new_df = scaler.fit_transform(new_df)
# Save the scaler object as a pickle file
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4127/584165801.py in <module>
#       1 # Apply MinMax scaling on the numerical columns
# ----> 2 test_X = scaler.fit_transform(new_df)
#       3 test_clusters = kmeans.predict(test_X)
#       4
#       5 # View the count of samples in each predicted cluster
#
# NameError: name 'scaler' is not defined
